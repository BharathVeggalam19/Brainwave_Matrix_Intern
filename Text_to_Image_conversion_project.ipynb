# %% [markdown]
# <a href="https://colab.research.google.com/github/BharathVeggalam19/Brainwave_Matrix_Intern/blob/main/Text_to_Image_conversion_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
from diffusers import StableDiffusionPipeline
from PIL import Image

# Load the model (use float16 for performance on supported GPUs)
pipeline = StableDiffusionPipeline.from_pretrained(
    "stabilityai/stable-diffusion-2-1",
    torch_dtype=torch.float16
).to("cuda")
# Out:
# 2025-07-29 11:08:53.893429: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1753787334.105875      36 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1753787334.161716      36 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# model_index.json:   0%|          | 0.00/537 [00:00<?, ?B/s]
# Fetching 13 files:   0%|          | 0/13 [00:00<?, ?it/s]
# vocab.json: 0.00B [00:00, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/824 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/633 [00:00<?, ?B/s]
# ...

# %%
# Ask user to enter a prompt
prompt = input("Enter your prompt for image generation: ")

# Generate the image
result = pipeline(prompt=prompt)
image = result.images[0]
# Out:
# Enter your prompt for image generation:  Ultra-wide-angle photograph of the Milky Way arching over a remote desert landscape, long exposure, high-resolution, realistic lighting
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
from IPython.display import display
display(image)
# Out:
# <PIL.Image.Image image mode=RGB size=768x768>
